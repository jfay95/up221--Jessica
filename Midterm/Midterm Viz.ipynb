# %% [markdown]
# # Midterm Assignment - Making graphs for midterm
# ## Jessica Fay
# ## Research Question - does SNAP acceptance associate with CHd in LA county?
# # Data sources: USC Neighborhood Data for Social Change data, ACS census data

# %%
# import pandas
import pandas as pd

# %%
#read in data of census and usc merged data
food = pd.read_csv('Data/midterm_JF.csv')
food
# Out:
#       geoid20_x        FIPS   ShapeSTArea  ShapeSTLength  pop_below_100_pct  \
# 0        101122  6037101122  2.845774e+07   31671.455840           4.429760
# 1        101220  6037101220  7.522093e+06   12698.783810          16.900661
# 2        101221  6037101221  3.812000e+06    9161.710543          20.601543
# 3        101222  6037101222  3.191371e+06    9980.600461          38.019875
# 4        102107  6037102107  1.390833e+08   63679.434270          12.399194
# ...         ...         ...           ...            ...                ...
# 1582     701902  6037701902  1.999589e+07   19865.289570          21.081974
# 1583     702002  6037702002  1.168575e+07   14132.916010           8.079848
# 1584     702102  6037702102  1.046411e+07   14134.196990          10.069859
# 1585     800412  6037800412  7.592319e+07   62472.172930          17.064352
# 1586     576602  6037576602  5.375975e+07   44322.754140          16.346973
#
#       pop_below_200_pct   chd_pct  total_pop  snap_rate  Age Total population  \
# 0             10.499266  5.107527       4247   2.354603                  4164
# 1             34.781456  6.201288       3583   8.372872                  3481
# 2             43.918018  5.587014       3723   2.686006                  3756
# 3             66.654396  5.590622       2690   7.434944                  2808
# 4             35.635082  6.808279       3920   2.551020                  3577
# ...                 ...       ...        ...        ...                   ...
# 1582          39.459015  4.802706       5022  15.929909                  5149
# 1583          23.415716  3.895420       6249   3.200512                  6185
# 1584          22.814789  4.293022       5914   1.690903                  5620
# 1585          21.017113  5.508799       3693   2.707826                  3682
# 1586          31.990622  4.397515       4876   4.101723                  4829
#
#       ...  0-19 years  20 to 44 years  45 to 64 years  65 years and over  \
# 0     ...         729            1039            1487                909
# 1     ...         686            1107            1119                569
# 2     ...         805            1336             882                733
# 3     ...         542            1021             786                459
# 4     ...         538            1161            1093                785
# ...   ...         ...             ...             ...                ...
# 1582  ...         305            2554            1342                948
# 1583  ...         933            2635            1488               1129
# 1584  ...         451            2242            1714               1213
# 1585  ...         989             659            1126                908
# 1586  ...         400            2380            1396                653
#
#       Percent 65 years and over  85 years and over  Hispanic or Latino  \
# 0                          21.8                149                 362
# 1                          16.3                 39                1463
# 2                          19.5                182                1204
# 3                          16.3                 70                1295
# 4                          21.9                212                 886
# ...                         ...                ...                 ...
# 1582                       33.7                311                 309
# 1583                       24.8                154                 901
# 1584                       26.3                155                 540
# 1585                       18.4                 33                 526
# 1586                       33.5                 16                1472
#
#       Percent Hispanic or Latino  Not Hispanic or Latino  geoid20_y
# 0                            8.7                    3802     101122
# 1                           42.0                    2018     101220
# 2                           32.1                    2552     101221
# 3                           46.1                    1513     101222
# 4                           24.8                    2691     102107
# ...                          ...                     ...        ...
# 1582                         6.0                    4840     701902
# 1583                        14.6                    5284     702002
# 1584                         9.6                    5080     702102
# 1585                        14.3                    3156     800412
# 1586                        30.5                    3357     576602
#
# [1587 rows x 22 columns]

# %%
#inspect data
food.shape
# Out:
# (1587, 22)

# %%
#Look at data type
food.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1587 entries, 0 to 1586
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   geoid20_x                   1587 non-null   int64
#  1   FIPS                        1587 non-null   int64
#  2   ShapeSTArea                 1587 non-null   float64
#  3   ShapeSTLength               1587 non-null   float64
#  4   pop_below_100_pct           1586 non-null   float64
#  5   pop_below_200_pct           1586 non-null   float64
#  6   chd_pct                     1587 non-null   float64
#  7   total_pop                   1587 non-null   int64
#  8   snap_rate                   1587 non-null   float64
#  9   Age Total population        1587 non-null   int64
#  10  Under 18 years              1587 non-null   int64
#  11  Percent Under 18 years      1467 non-null   float64
#  12  0-19 years                  1587 non-null   int64
#  13  20 to 44 years              1587 non-null   int64
#  14  45 to 64 years              1587 non-null   int64
#  15  65 years and over           1587 non-null   int64
#  16  Percent 65 years and over   1467 non-null   float64
#  17  85 years and over           1587 non-null   int64
#  18  Hispanic or Latino          1587 non-null   int64
#  19  Percent Hispanic or Latino  1587 non-null   float64
#  20  Not Hispanic or Latino      1587 non-null   int64
#  21  geoid20_y                   1587 non-null   int64
# dtypes: float64(9), int64(13)
# memory usage: 272.9 KB

# %%
food=pd.read_csv('Data/midterm_JF.csv', dtype= {'FIPS':str})
                 
food.head(3)
# Out:
#    geoid20_x        FIPS   ShapeSTArea  ShapeSTLength  pop_below_100_pct  \
# 0     101122  6037101122  2.845774e+07   31671.455840           4.429760
# 1     101220  6037101220  7.522093e+06   12698.783810          16.900661
# 2     101221  6037101221  3.812000e+06    9161.710543          20.601543
#
#    pop_below_200_pct   chd_pct  total_pop  snap_rate  Age Total population  \
# 0          10.499266  5.107527       4247   2.354603                  4164
# 1          34.781456  6.201288       3583   8.372872                  3481
# 2          43.918018  5.587014       3723   2.686006                  3756
#
#    ...  Percent Under 18 years  0-19 years  20 to 44 years  45 to 64 years  \
# 0  ...                    16.0         729            1039            1487
# 1  ...                    17.1         686            1107            1119
# 2  ...                    18.5         805            1336             882
#
#    65 years and over  Percent 65 years and over  85 years and over  \
# 0                909                       21.8                149
# 1                569                       16.3                 39
# 2                733                       19.5                182
#
#    Hispanic or Latino  Not Hispanic or Latino  geoid20_y
# 0                 362                    3802     101122
# 1                1463                    2018     101220
# 2                1204                    2552     101221
#
# [3 rows x 21 columns]

# %%
#confirming correct data types
food.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1587 entries, 0 to 1586
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   geoid20_x                   1587 non-null   int64
#  1   FIPS                        1587 non-null   int64
#  2   ShapeSTArea                 1587 non-null   float64
#  3   ShapeSTLength               1587 non-null   float64
#  4   pop_below_100_pct           1586 non-null   float64
#  5   pop_below_200_pct           1586 non-null   float64
#  6   chd_pct                     1587 non-null   float64
#  7   total_pop                   1587 non-null   int64
#  8   snap_rate                   1587 non-null   float64
#  9   Age Total population        1587 non-null   int64
#  10  Under 18 years              1587 non-null   int64
#  11  Percent Under 18 years      1467 non-null   float64
#  12  0-19 years                  1587 non-null   int64
#  13  20 to 44 years              1587 non-null   int64
#  14  45 to 64 years              1587 non-null   int64
#  15  65 years and over           1587 non-null   int64
#  16  Percent 65 years and over   1467 non-null   float64
#  17  85 years and over           1587 non-null   int64
#  18  Hispanic or Latino          1587 non-null   int64
#  19  Percent Hispanic or Latino  1587 non-null   float64
#  20  Not Hispanic or Latino      1587 non-null   int64
#  21  geoid20_y                   1587 non-null   int64
# dtypes: float64(9), int64(13)
# memory usage: 272.9 KB

# %% [markdown]
# # Now I will explore the data

# %%
#look at the mean and median population
food['total_pop'].mean() #mean per census tract
# Out:
# 4088.5198487712664

# %%
food['total_pop'].median() #median across census tracts
# Out:
# 3952.0

# %%
#look at mean and median snap acceptance rate
food['snap_rate'].mean() #mean per census tract
# Out:
# 8.171850235217391

# %%
food['snap_rate'].median() #median across census tracts
# Out:
# 6.4850845

# %%
#box plot
food.boxplot(column=['snap_rate'])
# Out:
# <Axes: >

# %% [markdown]
# # make boxplots for distribution of key variables

# %%
import plotly.express as px
import pandas as pd
df = pd.read_csv('Data/midterm_JF.csv')

# %%
#SNAP Rate
px.box(data_frame = df
       ,x = 'snap_rate', 
       labels ={
                "snap_rate": "Grocery Store SNAP Acceptance Rate"},
       
       title='Census Tract Grocery Store SNAP Acceptance Rate'
       )

# %%
# Coronary Heart Disease Percent
px.box(data_frame = df
       ,x = 'chd_pct', 
        labels ={
                "chd_pct": "CHD Rate"},
       title='Census Tract Prevalence of Coronary Heart Disease'
       )

# %% [markdown]
# # Look at distribution of hispanic because in LA, most SNAP participants are Hispanic

# %%
px.box(data_frame = df
       ,x = 'Percent Hispanic or Latino', title='Census Tract Percent Hispanic/Latino'
       )

# %% [markdown]
# # Look at distribution of % of census that are 100% below poverty threshold

# %%
px.box(data_frame = df
       ,x = 'pop_below_100_pct', 
       labels ={
                "pop_below_100_pct": "Percent of Pop Below 100% Poverty Threshold",},
       title='Census Tract Percent Below 100% of Poverty Threshold'
       )

# %% [markdown]
# # Initial Correlation of SNAP acceptance and CHD

# %%
 px.scatter(df, x="snap_rate", y="chd_pct",
            labels ={
                "chd_pct": "CHD Rate",
                "snap_rate": "Grocery Store SNAP Acceptance Rate"},
            title="Census Tract Coronary Heart Disease Rate vs. Grocery Store SNAP Acceptance Rate")

# %% [markdown]
# # Jessica - cleaned data for import and analysis, conducted data exploration and developed visualizations of key variables
